# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score,confusion_matrix,classification_report

sys.path.append(os.path.abspath("../"))
from src.data_loader import load_data

data = load_data("../data/raw/titanic.csv")

print(data.head())

#check for missing Value
#print(data.isnull().sum())

#Treat missing values
data.loc[:, 'Age']= data['Age'].fillna(data['Age'].median())

data.drop(columns=['Cabin'],inplace=True)

data.loc[:, 'Embarked']= data['Embarked'].fillna(data['Embarked'].mode()[0])



print(data.isnull().sum())
print(data.describe())

# Handle catagorical data Sex and Embarked
label_encoder_sex = LabelEncoder()

data['Sex'] = label_encoder_sex.fit_transform(data['Sex'])

label_encoder_embarked = LabelEncoder()

data['Embarked'] = label_encoder_embarked.fit_transform(data['Embarked'])

#print(data.head())
data = data.dropna()
#Select feature and Target variables


data.drop(columns=['PassengerId', 'Name', 'Ticket'], inplace=True)
print(data.info())

X = data.drop(columns='Survived')
y = data['Survived']

print(X.shape)
print(y.shape)

assert X.shape[0] == y.shape[0] ,"Miss match in the number of rows"

#Split the data to train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)
training_shape =X_train
testing_shape = X_test

print(f"traiming data sie is {training_shape} ")
print(f"Test shape is {testing_shape}")
print(data.isnull().sum())

# intialize the model 
model = LogisticRegression(max_iter=1000,random_state=42)

#fit model

model.fit(X_train,y_train)

#Predict the target for test

y_predict = model.predict(X_test)



# evaluate odel performance 
test_accuracy = accuracy_score(y_test,y_predict)

print(f"The accuracy of the model is :{test_accuracy}")

confussion_matrix = confusion_matrix(y_test,y_predict)
print(f"confusion matrx of the model is {confussion_matrix}")

classification_rep= classification_report(y_test,y_predict)
print(classification_rep)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB
# None
# (891, 7)
# (891,)
# traiming data sie is      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 826       3    1  28.0      0      0   56.4958         2
# 838       3    1  32.0      0      0   56.4958         2
# 763       1    0  36.0      1      2  120.0000         2
# 189       3    1  36.0      0      0    7.8958         2
# 109       3    0  28.0      1      0   24.1500         1
# ..      ...  ...   ...    ...    ...       ...       ...
# 277       2    1  28.0      0      0    0.0000         2
# 817       2    1  31.0      1      1   37.0042         0
# 255       3    0  29.0      0      2   15.2458         0
# 320       3    1  22.0      0      0    7.2500         2
# 836       3    1  21.0      0      0    8.6625         2
#
# [712 rows x 7 columns]
# Test shape is      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 770       3    1  24.0      0      0   9.5000         2
# 853       1    0  16.0      0      1  39.4000         2
# 144       2    1  18.0      0      0  11.5000         2
# 141       3    0  22.0      0      0   7.7500         2
# 261       3    1   3.0      4      2  31.3875         2
# ..      ...  ...   ...    ...    ...      ...       ...
# 71        3    0  16.0      5      2  46.9000         2
# 423       3    0  28.0      1      1  14.4000         2
# 342       2    1  28.0      0      0  13.0000         2
# 825       3    1  28.0      0      0   6.9500         1
# 293       3    0  24.0      0      0   8.8500         2
#
# [179 rows x 7 columns]
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# The accuracy of the model is :0.7374301675977654
# confusion matrx of the model is [[93 17]
#  [30 39]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80       110
#            1       0.70      0.57      0.62        69
#
#     accuracy                           0.74       179
#    macro avg       0.73      0.71      0.71       179
# weighted avg       0.73      0.74      0.73       179
