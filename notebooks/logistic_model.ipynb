# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

sys.path.append(os.path.abspath("../"))
from src.data_loader import load_data

data = load_data("../data/raw/titanic.csv")

print(data.head())

#check for missing Value
#print(data.isnull().sum())

#Treat missing values
data.loc[:, 'Age']= data['Age'].fillna(data['Age'].median())

data.drop(columns=['Cabin'],inplace=True)

data.loc[:, 'Embarked']= data['Embarked'].fillna(data['Embarked'].mode()[0])



print(data.isnull().sum())
print(data.describe())

# Handle catagorical data Sex and Embarked
label_encoder_sex = LabelEncoder()

data['Sex'] = label_encoder_sex.fit_transform(data['Sex'])

label_encoder_embarked = LabelEncoder()

data['Embarked'] = label_encoder_embarked.fit_transform(data['Embarked'])

#print(data.head())
data = data.dropna()
#Select feature and Target variables

X = data.drop(data['Survived'])
y = data['Survived']

print(X.info())
print(y.info())
#Split the data to train and test

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)
#training_shape =X_train
#testing_shape = X_test

#print(f"traiming data sie is {training_shape} ")
#print(f"Test shape is {testing_shape}")
print(data.isnull().sum())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...
